# %%
import pandas as pd 
import matplotlib.pyplot as plt
import pysd 
from math import isclose

# %%
model = pysd.read_vensim('Energy Drinks.mdl')

# %%
BAU = model.run()

# %%
BAU['Mg caffeine in body'],
# Out:
# (0.00     0.000000
#  0.25     0.000000
#  0.50     0.000000
#  0.75     0.000000
#  1.00     0.000000
#             ...
#  54.00    5.236939
#  54.25    5.117918
#  54.50    5.001601
#  54.75    4.887929
#  55.00    4.776839
#  Name: Mg caffeine in body, Length: 221, dtype: float64,)

# %%
BAU[['Mg caffeine in body', 'Mg caffeine in stomach']].plot(figsize = (12,7))
plt.hlines(y = 10, xmin = 0, xmax = 60, color = 'k', linestyles = 'dashed')
plt.vlines(x = 48, ymin = 0, ymax = 100, color = 'k');
